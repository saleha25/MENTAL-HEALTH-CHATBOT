# %%
import os
os.chdir(r"C:\Users\tellm\Desktop\Mental Health Screening & Well-Being Assessment .csv")

import pandas as pd

datasets = {
    "Cleaned Mental Health (Pakistan)": "data/external/Cleaned mental health data.csv",
    "CounselChat":                       "data/external/counsel_chat.csv",
    "Empathetic Counseling":             "data/external/empathetic_counseling.csv",
    "MentalChat16K":                     "data/external/mental_chat_16k.csv",
    "Mental Health Counseling":          "data/external/mental_health_counseling.csv",
    "Reddit Mental Health":              "data/external/reddit_mental_health.csv",
}

for name, path in datasets.items():
    try:
        df = pd.read_csv(path)
        print(f"✅ {name}")
        print(f"   Rows: {len(df)} | Columns: {len(df.columns)}")
        print(f"   Columns: {df.columns.tolist()[:5]}...")
        print()
    except Exception as e:
        print(f"❌ {name} — {e}")
        print()
# Out:
# ✅ Cleaned Mental Health (Pakistan)
#    Rows: 764 | Columns: 111
#    Columns: ['Unnamed: 0', 'Diagnosis', 'LowerBP', 'RespiratoryRate', 'Temp']...
#
# ✅ CounselChat
#    Rows: 2775 | Columns: 10
#    Columns: ['questionID', 'questionTitle', 'questionText', 'questionLink', 'topic']...
#
# ✅ Empathetic Counseling
#    Rows: 30937 | Columns: 2
#    Columns: ['input', 'label']...
#
# ✅ MentalChat16K
#    Rows: 16084 | Columns: 3
#    Columns: ['instruction', 'input', 'output']...
#
# ✅ Mental Health Counseling
#    Rows: 3512 | Columns: 2
#    Columns: ['Context', 'Response']...
#
# ✅ Reddit Mental Health
#    Rows: 151288 | Columns: 10
#    Columns: ['author', 'body', 'created_utc', 'id', 'num_comments']...
